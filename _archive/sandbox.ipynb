# %%
from sandbox import create_dataframe

# %%
mdf = create_dataframe(measurements=10)
# Out:
# 2024-09-26 18:43:12.839 | INFO     | sandbox:create_dataframe:21 - Measurement index: 1
# 2024-09-26 18:43:13.010 | INFO     | sandbox:test_speed:9 - Testing download speed...
# 2024-09-26 18:43:23.677 | INFO     | sandbox:test_speed:11 - Testing upload speed...
# 2024-09-26 18:43:33.834 | INFO     | sandbox:test_speed:13 - Getting results...
# 2024-09-26 18:43:33.835 | INFO     | sandbox:create_dataframe:36 - Applying delay of 2 seconds...
# 2024-09-26 18:43:35.836 | INFO     | sandbox:create_dataframe:21 - Measurement index: 2
# 2024-09-26 18:43:36.039 | INFO     | sandbox:test_speed:9 - Testing download speed...
# 2024-09-26 18:43:46.845 | INFO     | sandbox:test_speed:11 - Testing upload speed...
# 2024-09-26 18:43:57.055 | INFO     | sandbox:test_speed:13 - Getting results...
# 2024-09-26 18:43:57.056 | INFO     | sandbox:create_dataframe:36 - Applying delay of 2 seconds...
# 2024-09-26 18:43:59.057 | INFO     | sandbox:create_dataframe:21 - Measurement index: 3
# ...

# %%
# mdf.set_index('timestamp', inplace=True)
# mdf

# %%
import pandas as pd
mdf['date_time'] = pd.to_datetime(mdf['timestamp'])
mdf
# Out:
#                      timestamp  download_speed  upload_speed   ping  \
# 0  2024-09-26T15:43:13.010284Z       78.092816     90.843860  3.363
# 1  2024-09-26T15:43:36.039285Z       56.981587     90.217052  3.516
# 2  2024-09-26T15:43:59.260478Z       76.956047     89.198243  3.316
# 3  2024-09-26T15:44:22.362343Z       78.221347     87.537453  3.373
# 4  2024-09-26T15:44:45.507124Z       78.052894     89.337975  3.399
# 5  2024-09-26T15:45:08.569778Z       78.591311     89.629983  3.363
# 6  2024-09-26T15:45:31.692576Z       78.170668     89.241329  3.317
# 7  2024-09-26T15:45:54.817695Z       62.860762     88.510066  3.422
# 8  2024-09-26T15:46:17.998691Z       78.856975     89.591942  3.309
# 9  2024-09-26T15:46:40.982218Z       77.105039     90.077599  3.321
#
#                                           server_url server_name  \
# 0  http://spdf.fastpath.gr:8080/speedtest/upload.php      Athens
# 1  http://spdf.fastpath.gr:8080/speedtest/upload.php      Athens
# ...

# %%
mdf.plot('date_time',['download_speed', 'upload_speed'], kind='line')
# Out:
# <Axes: xlabel='date_time'>
